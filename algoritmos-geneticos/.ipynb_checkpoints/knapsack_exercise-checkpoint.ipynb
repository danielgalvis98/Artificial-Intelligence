# %% [markdown]
# # Knapsack problem
#
# + __Student 1: Daniel Galvis Torres__
# + __Student 2: Luis Fernando Muñoz__
#
# Given a list of items and a bag maximum capacity, find the best combination of items.
#
# The algorithm to complete:

# %%
import random
import math

class KnapsackGenetic:
  def __init__(self, params):
    self.ALL_NUMBERS = list(range(params["max_per_item"] + 1))
    self.params = params
    self.specimen = [None] * self.params["generation_size"]

    self.create_initial_population()

  def create_initial_population(self):
    self.specimen = list(map(
        lambda _: list(map(
            lambda _: random.choice(self.ALL_NUMBERS),
            [None] * len(self.params["items"])
        )),
        self.specimen
    ))

  def fitness(self, specimen):
    weiig = 0
    vals = 0
    for i in range(len(specimen)):
        weiig += specimen[i] * self.params["items"][i].weight
    if weiig > self.params["max_weight"]:
        return 0
    else:
        for i in range(len(specimen)):
            vals += specimen[i] * self.params["items"][i].value
    return vals

  def is_converged(self):
    if any(self.fitness(specimen) >= self.params["fit_threshold"] for specimen in self.specimen):
      return True

    return False

  def get_fit(self):
    evaluations = self.fitness_all()

    max_evaluation = max(evaluations)

    max_index = evaluations.index(max_evaluation)

    return self.specimen[max_index], max_evaluation

  def fitness_all(self):
    return list(map(self.fitness, self.specimen))

  def select_specimen(self, specimen_evaluations):
    specimen_and_evaluations = list(zip(self.specimen, specimen_evaluations))

    specimen_and_evaluations.sort(key=lambda e: e[1], reverse = True)
    #print(specimen_and_evaluations)
    n_top = params["select_top"]
    return list(map(lambda s: s[0], specimen_and_evaluations[:n_top]))
  
  def mutate(self, specimen):
    #print(specimen)
    newspec = [None] * len(self.params["items"])
    for i in range(len(specimen)):
        if random.uniform(0,1) < self.params["mutation_percentage"]:
            newspec[i] = random.choice(range(self.params["max_per_item"]+1))
            #print(newspec[i])
        else:
            newspec[i] = specimen[i]
    return newspec

  def generate_children(self, selected_specimen):  
    mutated_specimen = [None] * len(self.specimen)

    for i in range(len(mutated_specimen)):
      mutated_specimen[i] = self.mutate(random.choice(selected_specimen))

    return mutated_specimen

  def run(self):
    generation_number = 1

    while generation_number <= self.params["max_generations"] and not self.is_converged():
      top_generation = self.get_fit()
      top_str = "".join(str(top_generation[0]))
      
      print(f"Generation #{generation_number}:\t{top_str}\t{top_generation[1]}")

      specimen_evaluations = self.fitness_all()
      selected_specimen = self.select_specimen(specimen_evaluations)
      
      self.specimen = self.generate_children(selected_specimen)
      
      generation_number += 1
    
    return self.get_fit()

# %% [markdown]
# To run the algorithm:

# %%
class Item:
  def __init__(self, value, weight):
    self.value = value
    self.weight = weight

params = {
    "mutation_percentage": 0.2,
    "select_top": 2,
    "generation_size": 10,
    "fit_threshold": 36,
    "max_generations": 200,
    "max_weight": 15,
    "max_per_item": 3,
    "items": [Item(4, 12), Item(2, 2), Item(2, 1), Item(1, 1), Item(10,4)]
}

knapsack = KnapsackGenetic(params)
knapsack.run()
# Out:
# Generation #1:	[0, 2, 2, 1, 1]	19
# 2
# Generation #2:	[0, 0, 3, 3, 2]	29
# 2
# Generation #3:	[0, 0, 3, 3, 2]	29
# 2
# Generation #4:	[0, 1, 0, 1, 3]	33
# 2
# Generation #5:	[0, 1, 0, 1, 3]	33
# 2
# Generation #6:	[0, 1, 0, 1, 3]	33
# 2
# Generation #7:	[0, 1, 0, 1, 3]	33
# 2
# Generation #8:	[0, 1, 0, 1, 3]	33
# 2
# Generation #9:	[0, 1, 0, 1, 3]	33
# 2
# Generation #10:	[0, 1, 0, 1, 3]	33
# 2
# Generation #11:	[0, 1, 0, 1, 3]	33
# 2
# Generation #12:	[0, 1, 0, 1, 3]	33
# 2
# Generation #13:	[0, 1, 0, 1, 3]	33
# 2
# Generation #14:	[0, 1, 0, 1, 3]	33
# 2
# Generation #15:	[0, 1, 0, 1, 3]	33
# 2
# Generation #16:	[0, 1, 0, 1, 3]	33
# 2
# Generation #17:	[0, 1, 0, 1, 3]	33
# 2
# Generation #18:	[0, 1, 0, 1, 3]	33
# 2
# Generation #19:	[0, 1, 0, 1, 3]	33
# 2
# Generation #20:	[0, 1, 0, 1, 3]	33
# 2
# Generation #21:	[0, 1, 0, 1, 3]	33
# 2
# Generation #22:	[0, 1, 0, 1, 3]	33
# 2
# Generation #23:	[0, 1, 0, 1, 3]	33
# 2
# Generation #24:	[0, 1, 0, 1, 3]	33
# 2
# Generation #25:	[0, 1, 0, 1, 3]	33
# 2
# Generation #26:	[0, 1, 0, 1, 3]	33
# 2
# Generation #27:	[0, 1, 0, 1, 3]	33
# 2
# Generation #28:	[0, 1, 0, 1, 3]	33
# 2
# Generation #29:	[0, 1, 0, 1, 3]	33
# 2
# Generation #30:	[0, 1, 0, 1, 3]	33
# 2
# Generation #31:	[0, 1, 0, 1, 3]	33
# 2
# Generation #32:	[0, 1, 0, 1, 3]	33
# 2
# Generation #33:	[0, 1, 0, 1, 3]	33
# 2
# Generation #34:	[0, 1, 0, 1, 3]	33
# 2
# Generation #35:	[0, 1, 0, 1, 3]	33
# 2
# Generation #36:	[0, 1, 0, 1, 3]	33
# 2
# Generation #37:	[0, 1, 0, 1, 3]	33
# 2
# Generation #38:	[0, 1, 0, 1, 3]	33
# 2
# Generation #39:	[0, 1, 0, 1, 3]	33
# 2
# Generation #40:	[0, 1, 0, 1, 3]	33
# 2
# Generation #41:	[0, 1, 1, 0, 3]	34
# 2
# Generation #42:	[0, 1, 1, 0, 3]	34
# 2
# Generation #43:	[0, 1, 1, 0, 3]	34
# 2
# Generation #44:	[0, 1, 1, 0, 3]	34
# 2
# Generation #45:	[0, 1, 1, 0, 3]	34
# 2
# Generation #46:	[0, 1, 1, 0, 3]	34
# 2
# Generation #47:	[0, 1, 1, 0, 3]	34
# 2
# Generation #48:	[0, 1, 1, 0, 3]	34
# 2
# Generation #49:	[0, 1, 1, 0, 3]	34
# 2
# Generation #50:	[0, 1, 1, 0, 3]	34
# 2
# Generation #51:	[0, 1, 1, 0, 3]	34
# 2
# Generation #52:	[0, 1, 1, 0, 3]	34
# 2
# Generation #53:	[0, 1, 1, 0, 3]	34
# 2
# Generation #54:	[0, 1, 1, 0, 3]	34
# 2
# Generation #55:	[0, 1, 1, 0, 3]	34
# 2
# Generation #56:	[0, 1, 1, 0, 3]	34
# 2
# Generation #57:	[0, 1, 1, 0, 3]	34
# 2
# Generation #58:	[0, 1, 1, 0, 3]	34
# 2
# Generation #59:	[0, 1, 1, 0, 3]	34
# 2
# Generation #60:	[0, 1, 1, 0, 3]	34
# 2
# Generation #61:	[0, 1, 1, 0, 3]	34
# 2
# Generation #62:	[0, 1, 1, 0, 3]	34
# 2
# Generation #63:	[0, 1, 1, 0, 3]	34
# 2
# Generation #64:	[0, 1, 1, 0, 3]	34
# 2
# Generation #65:	[0, 0, 1, 2, 3]	34
# 2
# Generation #66:	[0, 0, 1, 2, 3]	34
# 2
# Generation #67:	[0, 0, 1, 2, 3]	34
# 2
# Generation #68:	[0, 1, 1, 0, 3]	34
# 2
# Generation #69:	[0, 1, 1, 0, 3]	34
# 2
# Generation #70:	[0, 1, 1, 0, 3]	34
# 2
# Generation #71:	[0, 1, 1, 0, 3]	34
# 2
# Generation #72:	[0, 1, 1, 0, 3]	34
# 2
# Generation #73:	[0, 1, 1, 0, 3]	34
# 2
# Generation #74:	[0, 1, 1, 0, 3]	34
# 2
# Generation #75:	[0, 1, 1, 0, 3]	34
# 2
# Generation #76:	[0, 1, 1, 0, 3]	34
# 2
# Generation #77:	[0, 1, 1, 0, 3]	34
# 2
# Generation #78:	[0, 1, 1, 0, 3]	34
# 2
# Generation #79:	[0, 1, 1, 0, 3]	34
# 2
# Generation #80:	[0, 1, 1, 0, 3]	34
# 2
# Generation #81:	[0, 1, 1, 0, 3]	34
# 2
# Generation #82:	[0, 1, 1, 0, 3]	34
# 2
# Generation #83:	[0, 1, 1, 0, 3]	34
# 2
# Generation #84:	[0, 1, 1, 0, 3]	34
# 2
# Generation #85:	[0, 1, 1, 0, 3]	34
# 2
# Generation #86:	[0, 1, 1, 0, 3]	34
# 2
# Generation #87:	[0, 1, 1, 0, 3]	34
# 2
# Generation #88:	[0, 1, 1, 0, 3]	34
# 2
# Generation #89:	[0, 1, 1, 0, 3]	34
# 2
# Generation #90:	[0, 1, 1, 0, 3]	34
# 2
# Generation #91:	[0, 1, 1, 0, 3]	34
# 2
# Generation #92:	[0, 1, 1, 0, 3]	34
# 2
# Generation #93:	[0, 1, 1, 0, 3]	34
# 2
# Generation #94:	[0, 1, 1, 0, 3]	34
# 2
# Generation #95:	[0, 1, 1, 0, 3]	34
# 2
# Generation #96:	[0, 1, 1, 0, 3]	34
# 2
# Generation #97:	[0, 1, 1, 0, 3]	34
# 2
# Generation #98:	[0, 1, 1, 0, 3]	34
# 2
# Generation #99:	[0, 1, 1, 0, 3]	34
# 2
# Generation #100:	[0, 1, 1, 0, 3]	34
# 2
# Generation #101:	[0, 1, 1, 0, 3]	34
# 2
# Generation #102:	[0, 1, 1, 0, 3]	34
# 2
# Generation #103:	[0, 1, 1, 0, 3]	34
# 2
# Generation #104:	[0, 1, 1, 0, 3]	34
# 2
# Generation #105:	[0, 1, 1, 0, 3]	34
# 2
# Generation #106:	[0, 1, 1, 0, 3]	34
# 2
# Generation #107:	[0, 1, 1, 0, 3]	34
# 2
# Generation #108:	[0, 1, 1, 0, 3]	34
# 2
# Generation #109:	[0, 1, 1, 0, 3]	34
# 2
# Generation #110:	[0, 1, 1, 0, 3]	34
# 2
# Generation #111:	[0, 1, 1, 0, 3]	34
# 2
# Generation #112:	[0, 1, 1, 0, 3]	34
# 2
# Generation #113:	[0, 1, 1, 0, 3]	34
# 2
# Generation #114:	[0, 1, 1, 0, 3]	34
# 2
# Generation #115:	[0, 1, 1, 0, 3]	34
# 2
# Generation #116:	[0, 1, 1, 0, 3]	34
# 2
# Generation #117:	[0, 1, 1, 0, 3]	34
# 2
# Generation #118:	[0, 1, 1, 0, 3]	34
# 2
# Generation #119:	[0, 1, 1, 0, 3]	34
# 2
# Generation #120:	[0, 1, 1, 0, 3]	34
# 2
# Generation #121:	[0, 1, 1, 0, 3]	34
# 2
# Generation #122:	[0, 1, 1, 0, 3]	34
# 2
# Generation #123:	[0, 1, 1, 0, 3]	34
# 2
# Generation #124:	[0, 1, 1, 0, 3]	34
# 2
# Generation #125:	[0, 1, 1, 0, 3]	34
# 2
# Generation #126:	[0, 1, 1, 0, 3]	34
# 2
# Generation #127:	[0, 1, 1, 0, 3]	34
# 2
# Generation #128:	[0, 1, 1, 0, 3]	34
# 2
# Generation #129:	[0, 1, 1, 0, 3]	34
# 2
# Generation #130:	[0, 1, 1, 0, 3]	34
# 2
# Generation #131:	[0, 1, 1, 0, 3]	34
# 2
# Generation #132:	[0, 1, 1, 0, 3]	34
# 2
# Generation #133:	[0, 1, 1, 0, 3]	34
# 2
# Generation #134:	[0, 1, 1, 0, 3]	34
# 2
# Generation #135:	[0, 1, 1, 0, 3]	34
# 2
# Generation #136:	[0, 1, 1, 0, 3]	34
# 2
# Generation #137:	[0, 1, 1, 0, 3]	34
# 2
# Generation #138:	[0, 1, 1, 0, 3]	34
# 2
# Generation #139:	[0, 1, 1, 0, 3]	34
# 2
# Generation #140:	[0, 1, 1, 0, 3]	34
# 2
# Generation #141:	[0, 1, 1, 0, 3]	34
# 2
# Generation #142:	[0, 1, 1, 0, 3]	34
# 2
# Generation #143:	[0, 1, 1, 0, 3]	34
# 2
# Generation #144:	[0, 1, 1, 0, 3]	34
# 2
# Generation #145:	[0, 1, 1, 0, 3]	34
# 2
# Generation #146:	[0, 1, 1, 0, 3]	34
# 2
# Generation #147:	[0, 1, 1, 0, 3]	34
# 2
# Generation #148:	[0, 1, 1, 0, 3]	34
# 2
# Generation #149:	[0, 1, 1, 0, 3]	34
# 2
# Generation #150:	[0, 1, 1, 0, 3]	34
# 2
# Generation #151:	[0, 1, 1, 0, 3]	34
# 2
# Generation #152:	[0, 1, 1, 0, 3]	34
# 2
# Generation #153:	[0, 1, 1, 0, 3]	34
# 2
# Generation #154:	[0, 1, 1, 0, 3]	34
# 2
# Generation #155:	[0, 1, 1, 0, 3]	34
# 2
# Generation #156:	[0, 1, 1, 0, 3]	34
# 2
# Generation #157:	[0, 1, 1, 0, 3]	34
# 2
# Generation #158:	[0, 1, 1, 0, 3]	34
# 2
# Generation #159:	[0, 1, 1, 0, 3]	34
# 2
# Generation #160:	[0, 1, 1, 0, 3]	34
# 2
# Generation #161:	[0, 1, 1, 0, 3]	34
# 2
# Generation #162:	[0, 1, 1, 0, 3]	34
# 2
# Generation #163:	[0, 1, 1, 0, 3]	34
# 2
# Generation #164:	[0, 1, 1, 0, 3]	34
# 2
# Generation #165:	[0, 1, 1, 0, 3]	34
# 2
# Generation #166:	[0, 1, 1, 0, 3]	34
# 2
# Generation #167:	[0, 1, 1, 0, 3]	34
# 2
# Generation #168:	[0, 1, 1, 0, 3]	34
# 2
# Generation #169:	[0, 1, 1, 0, 3]	34
# 2
# Generation #170:	[0, 1, 1, 0, 3]	34
# 2
# Generation #171:	[0, 1, 1, 0, 3]	34
# 2
# ([0, 0, 3, 0, 3], 36)
